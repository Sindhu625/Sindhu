# %%
import numpy as np

# Create a 2x3 empty array
arr = np.zeros((2, 3), dtype=int)   # allowed (just creates shape)

# Fill with 1 manually (no predefined ones() function)
for i in range(2):
    for j in range(3):
        arr[i][j] = 1

print(arr)
